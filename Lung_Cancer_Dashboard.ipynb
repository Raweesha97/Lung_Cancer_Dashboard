# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import numpy as np
from dash.dependencies import Input, Output
import plotly.express as px
import plotly.graph_objects as go
# Out:
# C:\Users\rawee\AppData\Local\Temp/ipykernel_24536/441822001.py:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\rawee\AppData\Local\Temp/ipykernel_24536/441822001.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
app = dash.Dash()

# %%
data = pd.read_csv('survey lung cancer.csv')
data_Yes = pd.DataFrame(data [(data["LUNG_CANCER"]== "YES")]).reset_index()
data_No = pd.DataFrame(data [(data["LUNG_CANCER"]== "NO")]).reset_index()

# %%
data_Yes
# Out:
#      index GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        0      M   69        1               2        2              1
# 1        1      M   74        2               1        1              1
# 2        5      F   75        1               2        1              1
# 3        6      M   52        2               1        1              1
# 4        7      F   51        2               2        2              2
# ..     ...    ...  ...      ...             ...      ...            ...
# 265    304      F   56        1               1        1              2
# 266    305      M   70        2               1        1              1
# 267    306      M   58        2               1        1              1
# 268    307      M   67        2               1        2              1
# 269    308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  2         2         2         2                  1
# 3                  1         2         1         2                  2
# 4                  1         2         2         1                  1
# ..               ...       ...       ...       ...                ...
# 265                2         2         1         1                  2
# 266                1         2         2         2                  2
# 267                1         1         2         2                  2
# 268                1         2         2         1                  2
# 269                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           1
# 3           2                    2                      1           2
# 4           1                    2                      2           1
# ..        ...                  ...                    ...         ...
# 265         2                    2                      2           1
# 266         2                    2                      1           2
# 267         2                    1                      1           2
# 268         2                    2                      1           2
# 269         1                    1                      2           1
#
#     LUNG_CANCER
# 0           YES
# 1           YES
# 2           YES
# 3           YES
# 4           YES
# ..          ...
# 265         YES
# 266         YES
# 267         YES
# 268         YES
# 269         YES
#
# [270 rows x 17 columns]

# %%
data.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0                    2                      2           2         YES
# 1                    2                      2           2         YES
# 2                    2                      1           2          NO
# 3                    1                      2           2          NO
# 4                    2                      1           1          NO

# %%
sheet1 = {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'50%','padding':'10px','background':'#fff5ba', 'border-radius':'10px','margin':'10px'}

sheet2 = {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'25%','padding':'10px','background':'#fff5ba', 'border-radius':'10px','margin':'10px'}

sheet3 = {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'21.25%','padding':'10px','background':'#fff5ba', 'border-radius':'10px','margin':'10px'}

sheet4 = {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'33.3%','padding':'10px','background':'black', 'border-radius':'10px','margin':'10px'}

fig_L = {
            'plot_bgcolor': '#454949',
            'paper_bgcolor': '#454949',
            #'title': 'Lung Cancer Patient',
            'xaxis':{'title':'Lung Cancer'},
            'yaxis':{'title':'Number of patients'},
            'font': {'color': '#ffff80','size':10},
            'legend':{'font':{'size':9}}
         }

# %%
data = pd.read_csv('survey lung cancer.csv')

# %%
Lung_cancer_status = data["LUNG_CANCER"].value_counts()
Gender = data["GENDER"].value_counts()
data["AGE"].value_counts()
# Out:
# 64    20
# 63    19
# 56    19
# 62    18
# 60    17
# 61    16
# 59    15
# 70    15
# 67    13
# 58    13
# 69    11
# 55    11
# 72    10
# 71    10
# 68     9
# 57     9
# 77     9
# 51     8
# 54     8
# 65     7
# 74     6
# 75     5
# 76     4
# 52     4
# 53     4
# 73     4
# 47     4
# 66     4
# 49     3
# 81     2
# 78     2
# 44     2
# 48     2
# 21     1
# 79     1
# 38     1
# 39     1
# 87     1
# 46     1
# Name: AGE, dtype: int64

# %%
dt1 = data [(data["LUNG_CANCER"]== "YES") & (data["WHEEZING"]== 2) ]["WHEEZING"].count()
dt2 = data [(data["LUNG_CANCER"]== "YES") & (data["WHEEZING"]== 1) ]["WHEEZING"].count()
dt3 = data [(data["LUNG_CANCER"]== "NO") & (data["WHEEZING"]== 2) ]["WHEEZING"].count()
dt4 = data [(data["LUNG_CANCER"]== "NO") & (data["WHEEZING"]== 1) ]["WHEEZING"].count()

# %%
dt5 = data [(data["LUNG_CANCER"]== "YES") & (data["COUGHING"]== 2) ]["COUGHING"].count()
dt6 = data [(data["LUNG_CANCER"]== "YES") & (data["COUGHING"]== 1) ]["COUGHING"].count()
dt7 = data [(data["LUNG_CANCER"]== "NO") & (data["COUGHING"]== 2) ]["COUGHING"].count()
dt8 = data [(data["LUNG_CANCER"]== "NO") & (data["COUGHING"]== 1) ]["COUGHING"].count()

# %%
dt9 = data_Yes[(data_Yes["LUNG_CANCER"]== "YES") & (data_Yes["FATIGUE "]== 2) ]["FATIGUE "].count()
dt10 = data_Yes[(data_Yes["LUNG_CANCER"]== "YES") & (data_Yes["FATIGUE "]== 1) ]["FATIGUE "].count()
dt11 = data_No[(data_No["LUNG_CANCER"]== "NO") & (data_No["FATIGUE "]== 2) ]["FATIGUE "].count()
dt12 = data_No[(data_No["LUNG_CANCER"]== "NO") & (data_No["FATIGUE "]== 1) ]["FATIGUE "].count()

# %%
colors = {
    'background': '#454949',
    'text': '#ffff80'
}

app.layout = html.Div([
    

    #title
    html.Div([
        html.H1("LUNG CANCER STATISTICS DASHBOARD")
    ],style={'text-align':'center','font-family':'Teko','font-size':20,'color':'white',
                    'padding':'5px','border-radius':'10px','margin':'5px' ,'background-color':colors['background']}),
    
    html.Div([

        html.Div([
            html.Div([
                html.H3("Total Respondents",style={'color': colors['text']}),
                html.H1(len(data),style={'color': colors['text']})
            ],style=sheet4),
            html.Div([
                html.H3("Total Patients",style={'color': colors['text']}),
                html.H1(len(data_Yes),style={'color': colors['text']})
            ],style=sheet4),
            html.Div([
                html.H3("Total Non-Patients",style={'color': colors['text']}),
                html.H1(len(data_No),style={'color': colors['text']})
            ],style=sheet4),
        ],style= {'display':'flex','flex-direction':'row','text-align':'center','color':'#4d5063','padding':'5px','background':colors['background'], 
            'border-radius':'10px','margin':'5px','width':'98%'}), 
 
    ]),


    
    
    html.Div([
        #left
        html.Div([
            #lung cancer patients
            html.Div([
                dcc.Graph(
                id='graph1',
                figure={
                        'data': [{'labels': ['Yes', 'No'], 'values': [Lung_cancer_status[0],Lung_cancer_status[1]],
                                  'type': 'pie', 'name': 'patientData'}],
                              'layout': {
                                    'plot_bgcolor': colors['background'],
                                    'paper_bgcolor': colors['background'],
                                    'title': 'Lung Cancer Patient',
                                    'font': {
                                    'color': colors['text']
                                     }
                                }
                        })
                
                
            ]),
            #gender distribution_pie
            html.Div([
                dcc.Graph(
                id='graph2',
                figure={
                        'data': [{'labels': ['Male', 'Female'], 'values': [Gender[0],Gender[1]],
                                  'type': 'pie', 'name': 'patientData'}],
                    
                               'layout': {
                                    'plot_bgcolor': colors['background'],
                                    'paper_bgcolor': colors['background'],
                                    'title': 'Gender Distribution',
                                    'font': {
                                    'color': colors['text']
                                     }
                                }
                    
                        })
            ]),
            #gender distribution_hist
            html.Div([
                dcc.Graph(id='graph3', style={'height':350},
                      figure={    
                      'layout':{
                      'plot_bgcolor': colors['background'],
                      'paper_bgcolor': colors['background'],
                      'title': 'Gender Distribution',
                      'font': {'color': colors['text']}
                              }
                      }),
             
            html.Label("Please select the range :", style={'color':'#ffff80'}),
                dcc.RangeSlider(
                    id='range1',
                    min = 0,
                    max = 85,
                    value = [0,5],
                    marks = {i : i for i in range(0,85,5)},
                    step = 1,
                ),
            ]),
        
        ],style={'display':'flex','flex-direction':'column','text-align':'center','text-align':'center','color':'#4d5063','padding':'5px','background':colors['background'], 
                 'border-radius':'10px','margin':'5px','width':'24%', 'height':'1300px'}),
        
        #right
        html.Div([
##########################################################################            
            
            #Uni-Variate Analysis
            html.H2("Uni-Variate Analysis",style={'color': colors['text'],'margin':'40px'}),
            
            html.Div([
                
                #age distribution with patient's status
                html.Div([
                    
                    html.Div([
                        html.H2("Age distribution with patient's status",style={'color': colors['text']}),
                        html.Label('Lung Cancer Patient',style={'color': colors['text']}),
                        dcc.Checklist(
                            id = "my_checklist",
                            options=[
                                {'label': 'Yes', 'value': 'YES'},
                                {'label': 'No', 'value': 'NO'}
                            ],
                            value=['Yes', 'NO'],
                            style={'color':'white'}
                        ),
                        ],style={'text-align':'center','fontSize':20,'font-weight':'bold','color':'white','background':colors['background'],'border-radius':'3px','margin':'4px','padding':'5px','width':'98%'}),
                    
                    dcc.Graph(id='graph4', style={'height':'70vh'},
                              figure={
                                  'layout':{
                                      'plot_bgcolor': colors['background'],
                                      'paper_bgcolor': colors['background'],
                                      'font': {'color': colors['text']}
                                  }
                              }),
                    
                    
                ],style=sheet1),
                #Gender_Lung Cancer Patient_pie
                html.Div([
                    
                    html.Div([
                        html.H2('Gender',style={'color': colors['text']}),
                        html.Label('Lung Cancer Patient',style={'color': colors['text']}),
                        dcc.RadioItems(
                            id='cancer',
                            options=[{'label':'Yes', 'value':'YES'},
                                     {'label':'No', 'value':'NO'}
                                    ],
                            value='YES',
                            style={'color':'white'}
                        ),
                        ],style={'fontSize':20,'font-weight':'bold','color':'white','background':colors['background'],'border-radius':'3px','margin':'4px','padding':'5px','width':'98%'}),
                   
                    dcc.Graph(id='pie2',style={'height':'70vh'},
                              figure={
                                  'layout':{
                                      'plot_bgcolor': colors['background'],
                                      'paper_bgcolor': colors['background'],
                                      'font': {'color': colors['text']}
                                  }
                              }
                             )

                ],style=sheet1),
                
                
                
                
        ],style={'display':'flex','flex-direction':'row','text-align':'center','color':'#4d5063','padding':'5px','background':colors['background'], 
            'border-radius':'10px','margin':'5px','width':'98%'}),     
###############################################################################################################################           
        html.Div([
               #####  INDICATORS #####    
                ],style={'background':'#664433','height':'270px','margin':'10px','border-radius':'10px'}),  

        ],style={'display':'flex','flex-direction':'column','text-align':'center','color':'#4d5063','padding':'5px','background':'black', 
                                        'border-radius':'10px','margin':'5px','width':'74%'}),
    ],style = {'border-radius':'10px','display':'flex', 'flex-direction':'row','background':'#000000'}),
############################################################################################################################         

    
    html.Div([
        
            html.Div([  
            html.H2("Lung Cancer Patient",style={'fontSize':35,'text-align':'center','border-radius':'10px','padding':'10px','color':'#ffffff','margin':'10px','background':'#224466'} )     
            ]), 
        
            html.Div([
########################################################...........YES..........#################################################
                dcc.Tabs([
                    dcc.Tab(label='YES', children=[
                        
                        #habits
                        html.Div([
                            
                            html.H2("Habits",style={'color': colors['text']})
                        ],style={'text-align':'center','font-family':'Teko','font-size':15,
                                 'padding':'5px','background':'#ffffff', 'border-radius':'10px','width':'98%','margin':'5px','background':colors['background']}),
                        
                        html.Div([
                            #combo_boxes
                            html.Div([
                                
                                #select_factor
                                html.Div([
                                    html.P("Select Factor:"),
                                    dcc.Dropdown(
                                        id='factor',
                                        value='SMOKING',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['SMOKING','ALCOHOL_CONSUMING']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),
                                ],style={'fontSize':20,'font-weight':'bold','color':'white','background':colors['background'],'border-radius':'25px','margin':'30px','padding':'30px'}),
                            
                            ], style =  {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'50%','height':'50%','padding':'10px','background':'#fff5ba', 'border-radius':'25px','margin':'20px'}),
                            
                            
                            #smoking_donut
                            html.Div([
                                dcc.Graph(id="donut1",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background'],
                                                  'paper_bgcolor': colors['background'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         )
                            
                            ], style = sheet1),
                        
                        ], style={'display':'flex', 'flex-direction':'row','width':'98%','text-align':'center','font-family':'Teko','font-size':15,
                                  'padding':'5px','background':'#ffffff', 'border-radius':'10px','margin':'5px','background':colors['background']}),
###############################################################################################################################                        
                        
                        #special symptoms
                        html.Div([
                            
                            html.H2("Symptoms",style={'color': colors['text']})
                        ],style={'text-align':'center','font-family':'Teko','font-size':15,
                                 'padding':'5px','background':'#ffffff', 'border-radius':'10px','width':'98%','margin':'5px','background':colors['background']}),
                        
                        html.Div([
                                
                            #select_factor
                            html.Div([
                                    html.H3("Select Factor:"),
                                    dcc.Dropdown(
                                        id='fac1',
                                        value = 'YELLOW_FINGERS',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['YELLOW_FINGERS','SWALLOWING_DIFFICULTY','CHEST_PAIN','SHORTNESS_OF_BREATH']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),

                                dcc.Graph(id="donut2",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background'],
                                                  'paper_bgcolor': colors['background'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         
                                         )
                            
                            ], style = sheet1),
                            
                            #select_factor
                            html.Div([
                                    html.H3("Select Factor:"),
                                    dcc.Dropdown(
                                        id='fac2',
                                        value = 'WHEEZING',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['WHEEZING','COUGHING','FATIGUE ']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),

                                dcc.Graph(id="barplot1",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background'],
                                                  'paper_bgcolor': colors['background'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         
                                         )
                            
                            ], style = sheet1),
                        
                        ], style={'display':'flex', 'flex-direction':'row','width':'98%','text-align':'center','font-family':'Teko','font-size':15,
            'padding':'5px','background':'#ffffff', 'border-radius':'10px','margin':'5px','background':colors['background']}),
                        
                        
                        #External Factors
                        html.Div([
                            html.H2("External Factors",style={'color': colors['text']})
                        ],style={'text-align':'center','font-family':'Teko','font-size':15,
                                 'padding':'5px','background':'#ffffff', 'border-radius':'10px','width':'98%','margin':'5px','background':colors['background']}),
                        
                        html.Div([
                            #combo_boxes
                            html.Div([
                                
                                #select_factor
                                html.Div([
                                    html.P("Select Factor:"),
                                    dcc.Dropdown(
                                        id='fact3',
                                        value='CHRONIC_DISEASE',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['CHRONIC_DISEASE','ANXIETY','PEER_PRESSURE','ALLERGY ']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),
                                ],style={'fontSize':20,'font-weight':'bold','color':'white','background':colors['background'],'border-radius':'25px','margin':'30px','padding':'30px'}),
                                
                                #select graph
                                html.Div([
                                    html.P("Select Graph Type:"),
                                    dcc.Dropdown(
                                        id='graph_type',
                                        value='Bar Chart',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['Bar Chart', 'Pie Chart']],
                                        clearable=False,
                        style={'color':'black'}
                                    ),
                                ],style={'fontSize':20,'font-weight':'bold','color':'white','background':colors['background'],'border-radius':'25px','margin':'30px','padding':'30px'})
                            
                            ], style =  {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'50%','padding':'10px','background':'#fff5ba', 'border-radius':'25px','margin':'20px'}),
                            
                            #external factor plot
                            html.Div([
                                dcc.Graph(id="barplot2",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background'],
                                                  'paper_bgcolor': colors['background'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         
                                         )
                            
                            ], style = sheet1),
                        
                        ], style={'display':'flex', 'flex-direction':'row','width':'98%','text-align':'center','font-family':'Teko','font-size':15,
                                  'padding':'5px','background':'#ffffff', 'border-radius':'10px','margin':'5px','background':colors['background']}),
                        
                        
                    ]),
############################################............YES END...........######################################################
                    
                    dcc.Tab(label='NO', children=[
                        
############################################............NO...........######################################################                        
                        
                        #habits
                        html.Div([
                            
                            html.H2("Habits",style={'color': colors['text']})
                        ],style={'text-align':'center','font-family':'Teko','font-size':15,
                                 'padding':'5px','background':'#ffffff', 'border-radius':'10px','width':'98%','margin':'5px','background':colors['background']}),
                        
                        html.Div([
                            #combo_boxes
                            html.Div([
                                
                                #select_factor
                                html.Div([
                                    html.P("Select Factor:"),
                                    dcc.Dropdown(
                                        id='factor_no',
                                        value='SMOKING',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['SMOKING','ALCOHOL_CONSUMING']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),
                                ],style={'fontSize':20,'font-weight':'bold','color':'white','background':colors['background'],'border-radius':'25px','margin':'30px','padding':'30px'}),
                            
                            ], style =  {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'50%','height':'50%','padding':'10px','background':'#fff5ba', 'border-radius':'25px','margin':'20px'}),
                            
                            
                            #smoking_donut
                            html.Div([
                                dcc.Graph(id="donut1_no",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background'],
                                                  'paper_bgcolor': colors['background'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         )
                            
                            ], style = sheet1),
                        
                        ], style={'display':'flex', 'flex-direction':'row','width':'98%','text-align':'center','font-family':'Teko','font-size':15,
                                  'padding':'5px','background':'#ffffff', 'border-radius':'10px','margin':'5px','background':colors['background']}),
###############################################################################################################################                        
                        
                        #special symptoms
                        html.Div([
                            
                            html.H2("Symptoms",style={'color': colors['text']})
                        ],style={'text-align':'center','font-family':'Teko','font-size':15,
                                 'padding':'5px','background':'#ffffff', 'border-radius':'10px','width':'98%','margin':'5px','background':colors['background']}),
                        
                        html.Div([
                                
                            #select_factor
                            html.Div([
                                    html.H3("Select Factor:"),
                                    dcc.Dropdown(
                                        id='fac1_no',
                                        value = 'YELLOW_FINGERS',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['YELLOW_FINGERS','SWALLOWING_DIFFICULTY','CHEST_PAIN','SHORTNESS_OF_BREATH']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),

                                dcc.Graph(id="donut2_no",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background'],
                                                  'paper_bgcolor': colors['background'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         
                                         )
                            
                            ], style = sheet1),
                            
                            #select_factor
                            html.Div([
                                    html.H3("Select Factor:"),
                                    dcc.Dropdown(
                                        id='fac2_no',
                                        value = 'WHEEZING',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['WHEEZING','COUGHING','FATIGUE ']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),

                                dcc.Graph(id="barplot1_no",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background'],
                                                  'paper_bgcolor': colors['background'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         
                                         )
                            
                            ], style = sheet1),
                        
                        ], style={'display':'flex', 'flex-direction':'row','width':'98%','text-align':'center','font-family':'Teko','font-size':15,
            'padding':'5px','background':'#ffffff', 'border-radius':'10px','margin':'5px','background':colors['background']}),
                        
                       
                        #External Factors
                        html.Div([
                            html.H2("External Factors",style={'color': colors['text']})
                        ],style={'text-align':'center','font-family':'Teko','font-size':15,
                                 'padding':'5px','background':'#ffffff', 'border-radius':'10px','width':'98%','margin':'5px','background':colors['background']}),
                        
                        html.Div([
                            #combo_boxes
                            html.Div([
                                
                                #select_factor
                                html.Div([
                                    html.P("Select Factor:"),
                                    dcc.Dropdown(
                                        id='fact3_no',
                                        value='CHRONIC_DISEASE',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['CHRONIC_DISEASE','ANXIETY','PEER_PRESSURE','ALLERGY ']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),
                                ],style={'fontSize':20,'font-weight':'bold','color':'white','background':colors['background'],'border-radius':'25px','margin':'30px','padding':'30px'}),
                                
                                #select graph
                                html.Div([
                                    html.P("Select Graph Type:"),
                                    dcc.Dropdown(
                                        id='graph_type_no',
                                        value='Bar Chart',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['Bar Chart', 'Pie Chart']],
                                        clearable=False,
                        style={'color':'black'}
                                    ),
                                ],style={'fontSize':20,'font-weight':'bold','color':'white','background':colors['background'],'border-radius':'25px','margin':'30px','padding':'30px'})
                            
                            ], style =  {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'50%','padding':'10px','background':'#fff5ba', 'border-radius':'25px','margin':'20px'}),
                            
                            #external factor plot
                            html.Div([
                                dcc.Graph(id="barplot2_no",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background'],
                                                  'paper_bgcolor': colors['background'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         
                                         )
                            
                            ], style = sheet1),
                        
                        ], style={'display':'flex', 'flex-direction':'row','width':'98%','text-align':'center','font-family':'Teko','font-size':15,
                                  'padding':'5px','background':'#ffffff', 'border-radius':'10px','margin':'5px','background':colors['background']}),
                        
                        
                    ]),
############################################............NO END...........######################################################            
                ])
                
                
                
    ])
            
          

    ]),
    


],style = {'border-radius':'10px','padding':'5px','margin':'5px','display':'flex', 'flex-direction':'column','background':'black', 'width':'100%'})

# %%
@app.callback(
    Output('graph3', 'figure'),
    [Input('range1', 'value')])

def generate_graph1(ranger):
    
    dt = data[(data['AGE']>=ranger[0]) & (data['AGE']<=ranger[1])]
    fig = px.histogram(dt,x = "AGE", nbins = 10, title="Age Distribution")
    fig.update_layout({'plot_bgcolor':colors['background'],
                       'paper_bgcolor': colors['background'],
                       'font': {'color': colors['text']}
                      })

    return fig

# %%
@app.callback(
    Output("graph4", "figure"), 
    [Input("my_checklist","value")])

def update_graph(options_chosen):
    
    dff = data[data["LUNG_CANCER"].isin(options_chosen)]
    print(dff["LUNG_CANCER"].unique())
    
    fig = px.box(dff,x="LUNG_CANCER", y="AGE")
    
    fig.update_layout({'plot_bgcolor':colors['background'],
                'paper_bgcolor': colors['background'],
                 'font': {'color': colors['text']}
                })    
    
    return fig

# %%
@app.callback(
    Output('pie2','figure'),
    Input('cancer', 'value')
)
def generate_graph(cancer):
    
    if(cancer=='YES' or cancer=='NO'):
            dt=data[data['LUNG_CANCER']==cancer]['GENDER'].value_counts()
            fig = px.pie(values=dt,names=["Male", "Female"])
            fig.update_layout({'plot_bgcolor':colors['background'],
                       'paper_bgcolor': colors['background'],
                       'font': {'color': colors['text']}
                      })

    return fig

# %%
@app.callback(
    Output("donut1", "figure"), 
    [Input("factor", "value")])

def generate_chart(factor):
    
    if(factor=='SMOKING'):
        dt=data_Yes['SMOKING'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Smoking")        
        
    if(factor=='ALCOHOL_CONSUMING'):
        dt=data_Yes['ALCOHOL CONSUMING'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="ALCOHOL_CONSUMING")

    fig.update_layout({'plot_bgcolor':colors['background'],
                'paper_bgcolor': colors['background'],
                 'font': {'color': colors['text']}
                })    
    
    return fig

# %%
########################
@app.callback(
    Output("donut1_no", "figure"), 
    [Input("factor_no", "value")])

def generate_chart(factor):
    
    if(factor=='SMOKING'):
        dt=data_No['SMOKING'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Smoking")        
        
    if(factor=='ALCOHOL_CONSUMING'):
        dt=data_No['ALCOHOL CONSUMING'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="ALCOHOL_CONSUMING")

    fig.update_layout({'plot_bgcolor':colors['background'],
                'paper_bgcolor': colors['background'],
                 'font': {'color': colors['text']}
                })    
    
    return fig

# %%
@app.callback(
    Output("donut2", "figure"), 
    [Input("fac1", "value")])

def generate_chart(fac1):
    
    if(fac1=='YELLOW_FINGERS'):
        dt=data_Yes['YELLOW_FINGERS'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Yellow Fingers")      
        
    if(fac1=='SHORTNESS_OF_BREATH'):
        dt=data_Yes['SHORTNESS OF BREATH'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Shortness Of Breath")
        
    if(fac1=='CHEST_PAIN'):
        dt=data_Yes['CHEST PAIN'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Chest Pain")

    if(fac1=='SWALLOWING_DIFFICULTY'):
        dt=data_Yes['SWALLOWING DIFFICULTY'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Swallowing Difficulty")
        
    fig.update_layout({'plot_bgcolor':colors['background'],
                'paper_bgcolor': colors['background'],
                 'font': {'color': colors['text']}
                })    
    
    return fig

# %%
##################################
@app.callback(
    Output("donut2_no", "figure"), 
    [Input("fac1_no", "value")])

def generate_chart(fac1):
    
    if(fac1=='YELLOW_FINGERS'):
        dt=data_No['YELLOW_FINGERS'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Yellow Fingers")      
        
    if(fac1=='SHORTNESS_OF_BREATH'):
        dt=data_No['SHORTNESS OF BREATH'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Shortness Of Breath")
        
    if(fac1=='CHEST_PAIN'):
        dt=data_No['CHEST PAIN'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Chest Pain")

    if(fac1=='SWALLOWING_DIFFICULTY'):
        dt=data_No['SWALLOWING DIFFICULTY'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Swallowing Difficulty")
        
    fig.update_layout({'plot_bgcolor':colors['background'],
                'paper_bgcolor': colors['background'],
                 'font': {'color': colors['text']}
                })    
    
    return fig

# %%
@app.callback(
    Output("barplot1", "figure"), 
    [Input("fac2", "value")])

def generate_chart(fac2):
    
    if(fac2=='WHEEZING'):
        dt = pd.DataFrame((((data_Yes['WHEEZING'].value_counts())/len(data_Yes))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="WHEEZING")      
        
    if(fac2=='COUGHING'):
        dt = pd.DataFrame((((data_Yes['COUGHING'].value_counts())/len(data_Yes))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="COUGHING")
        
    if(fac2=='FATIGUE '):
        dt = pd.DataFrame((((data_Yes['FATIGUE '].value_counts())/len(data_Yes))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="FATIGUE")
        
    fig.update_layout({'plot_bgcolor':colors['background'],
                'paper_bgcolor': colors['background'],
                 'font': {'color': colors['text']}
                })    
    
    return fig

# %%
########################
@app.callback(
    Output("barplot1_no", "figure"), 
    [Input("fac2_no", "value")])

def generate_chart(fac2):
    
    if(fac2=='WHEEZING'):
        dt = pd.DataFrame((((data_No['WHEEZING'].value_counts())/len(data_No))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="WHEEZING")      
        
    if(fac2=='COUGHING'):
        dt = pd.DataFrame((((data_No['COUGHING'].value_counts())/len(data_No))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="COUGHING")
        
    if(fac2=='FATIGUE '):
        dt = pd.DataFrame((((data_No['FATIGUE '].value_counts())/len(data_No))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="FATIGUE")
        
    fig.update_layout({'plot_bgcolor':colors['background'],
                'paper_bgcolor': colors['background'],
                 'font': {'color': colors['text']}
                })    
    
    return fig

# %%
@app.callback(
    Output("barplot2", "figure"), 
    [Input("fact3", "value"),Input("graph_type","value")])

def generate_chart(fact3,graph_type):
    
    if(fact3=='CHRONIC_DISEASE' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_Yes['CHRONIC DISEASE'].value_counts())/len(data_Yes))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="CHRONIC DISEASE")
        
    if(fact3=='CHRONIC_DISEASE' and graph_type=='Pie Chart'):
        dt=data_Yes['CHRONIC DISEASE'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="CHRONIC DISEASE")        
        
    if(fact3=='ANXIETY' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_Yes['ANXIETY'].value_counts())/len(data_Yes))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="ANXIETY")
        
    if(fact3=='ANXIETY' and graph_type=='Pie Chart'):
        dt=data_Yes['ANXIETY'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="ANXIETY")
        
    if(fact3=='PEER_PRESSURE' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_Yes['PEER_PRESSURE'].value_counts())/len(data_Yes))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="PEER_PRESSURE")
        
    if(fact3=='PEER_PRESSURE' and graph_type=='Pie Chart'):
        dt=data_Yes['PEER_PRESSURE'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="PEER_PRESSURE")
        
    if(fact3=='ALLERGY ' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_Yes['ALLERGY '].value_counts())/len(data_Yes))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="ALLERGY")
        
    if(fact3=='ALLERGY ' and graph_type=='Pie Chart'):
        dt=data_Yes['ALLERGY '].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="ALLERGY")
        
    fig.update_layout({'plot_bgcolor':colors['background'],
                'paper_bgcolor': colors['background'],
                 'font': {'color': colors['text']}
                })
        
    return fig

# %%
#########################
@app.callback(
    Output("barplot2_no", "figure"), 
    [Input("fact3_no", "value"),Input("graph_type_no","value")])

def generate_chart(fact3,graph_type):
    
    if(fact3=='CHRONIC_DISEASE' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_No['CHRONIC DISEASE'].value_counts())/len(data_No))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="CHRONIC DISEASE")
        
    if(fact3=='CHRONIC_DISEASE' and graph_type=='Pie Chart'):
        dt=data_No['CHRONIC DISEASE'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="CHRONIC DISEASE")        
        
    if(fact3=='ANXIETY' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_No['ANXIETY'].value_counts())/len(data_No))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="ANXIETY")
        
    if(fact3=='ANXIETY' and graph_type=='Pie Chart'):
        dt=data_No['ANXIETY'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="ANXIETY")
        
    if(fact3=='PEER_PRESSURE' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_No['PEER_PRESSURE'].value_counts())/len(data_No))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="PEER_PRESSURE")
        
    if(fact3=='PEER_PRESSURE' and graph_type=='Pie Chart'):
        dt=data_No['PEER_PRESSURE'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="PEER_PRESSURE")
        
    if(fact3=='ALLERGY ' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_No['ALLERGY '].value_counts())/len(data_No))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="ALLERGY")
        
    if(fact3=='ALLERGY ' and graph_type=='Pie Chart'):
        dt=data_No['ALLERGY '].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="ALLERGY")
        
    fig.update_layout({'plot_bgcolor':colors['background'],
                'paper_bgcolor': colors['background'],
                 'font': {'color': colors['text']}
                })
        
    return fig

# %%
if __name__== '__main__':
    app.run_server(port=8095)
# Out:
# Dash is running on http://127.0.0.1:8095/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8095/ (Press CTRL+C to quit)
# 127.0.0.1 - - [07/Jan/2022 20:52:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:46] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:46] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:46] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:46] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:46] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:46] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:46] "POST /_dash-update-component HTTP/1.1" 200 -
# ['NO']
# 127.0.0.1 - - [07/Jan/2022 20:52:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Jan/2022 20:52:57] "POST /_dash-update-component HTTP/1.1" 200 -
